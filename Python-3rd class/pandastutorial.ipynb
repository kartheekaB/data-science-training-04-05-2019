# %% [markdown]
# # This note book is for pandas
# ### 1st will be file reading

# %%
import pandas as pd

# %%
pd.Series([1,2,3,4,5],index=[11,12,13,14,15])
# Out:
# 11    1
# 12    2
# 13    3
# 14    4
# 15    5
# dtype: int64

# %%
olympic=pd.read_csv("D:/Desktop/Desktop_Important/ATI/olympics.csv",skiprows=4)

# %%
type(olympic)
# Out:
# pandas.core.frame.DataFrame

# %%
olympic.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens   1896.0  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens   1896.0  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens   1896.0  Aquatics   Swimming                 NaN  AUT    Men
# 3     NaN      NaN       NaN        NaN                 NaN  NaN    NaN
# 4  Athens   1896.0  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2              100m freestyle            M  Silver
# 3                         NaN          NaN     NaN
# 4  100m freestyle for sailors            M    Gold

# %%
olympic.head(2)
# Out:
#      City  Edition     Sport Discipline           Athlete  NOC Gender  \
# 0  Athens   1896.0  Aquatics   Swimming     HAJOS, Alfred  HUN    Men
# 1  Athens   1896.0  Aquatics   Swimming  HERSCHMANN, Otto  AUT    Men
#
#             Event Event_gender   Medal
# 0  100m freestyle            M    Gold
# 1  100m freestyle            M  Silver

# %%
olympic.columns.tolist()
# Out:
# ['City',
#  'Edition',
#  'Sport',
#  'Discipline',
#  'Athlete',
#  'NOC',
#  'Gender',
#  'Event',
#  'Event_gender',
#  'Medal']

# %%
olympic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29217 entries, 0 to 29216
# Data columns (total 10 columns):
# City            29216 non-null object
# Edition         29216 non-null float64
# Sport           29216 non-null object
# Discipline      29216 non-null object
# Athlete         29215 non-null object
# NOC             29216 non-null object
# Gender          29216 non-null object
# Event           29216 non-null object
# Event_gender    29216 non-null object
# Medal           29216 non-null object
# dtypes: float64(1), object(9)
# memory usage: 2.2+ MB

# %%
olympic.shape
# Out:
# (29217, 10)

# %%
olympic.describe()
# Out:
#             Edition
# count  29216.000000
# mean    1967.713171
# std       32.406293
# min     1896.000000
# 25%     1948.000000
# 50%     1976.000000
# 75%     1996.000000
# max     2008.000000

# %%
olympic["City"]
# Out:
# 0    Athens
# 1    Athens
# 2    Athens
# 3       NaN
# 4    Athens
# Name: City, dtype: object

# %%
olympic[["City","Edition"]]
# Out:
#           City  Edition
# 0       Athens   1896.0
# 1       Athens   1896.0
# 2       Athens   1896.0
# 3          NaN      NaN
# 4       Athens   1896.0
# 5       Athens   1896.0
# 6       Athens   1896.0
# 7       Athens   1896.0
# 8       Athens   1896.0
# 9       Athens   1896.0
# 10      Athens   1896.0
# 11      Athens   1896.0
# 12      Athens   1896.0
# 13      Athens   1896.0
# 14      Athens   1896.0
# 15      Athens   1896.0
# 16      Athens   1896.0
# 17      Athens   1896.0
# 18      Athens   1896.0
# 19      Athens   1896.0
# 20      Athens   1896.0
# 21      Athens   1896.0
# 22      Athens   1896.0
# 23      Athens   1896.0
# 24      Athens   1896.0
# 25      Athens   1896.0
# 26      Athens   1896.0
# 27      Athens   1896.0
# 28      Athens   1896.0
# 29      Athens   1896.0
# ...        ...      ...
# 29187  Beijing   2008.0
# 29188  Beijing   2008.0
# 29189  Beijing   2008.0
# 29190  Beijing   2008.0
# 29191  Beijing   2008.0
# 29192  Beijing   2008.0
# ...

# %%
olympic.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens   1896.0  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens   1896.0  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens   1896.0  Aquatics   Swimming                 NaN  AUT    Men
# 3     NaN      NaN       NaN        NaN                 NaN  NaN    NaN
# 4  Athens   1896.0  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2              100m freestyle            M  Silver
# 3                         NaN          NaN     NaN
# 4  100m freestyle for sailors            M    Gold

# %%
olympic["Medal"].value_counts()
# Out:
# Gold      9850
# Bronze    9688
# Silver    9678
# Name: Medal, dtype: int64

# %% [markdown]
# # Missing Value Treatment

# %%
olympic.isnull().sum()
# Out:
# City            1
# Edition         1
# Sport           1
# Discipline      1
# Athlete         2
# NOC             1
# Gender          1
# Event           1
# Event_gender    1
# Medal           1
# dtype: int64

# %%
olympic[olympic.isnull().any(axis=1)]
# Out:
#      City  Edition     Sport Discipline Athlete  NOC Gender           Event  \
# 2  Athens   1896.0  Aquatics   Swimming     NaN  AUT    Men  100m freestyle
# 3     NaN      NaN       NaN        NaN     NaN  NaN    NaN             NaN
#
#   Event_gender   Medal
# 2            M  Silver
# 3          NaN     NaN

# %%
olympic[olympic.isnull().all(axis=1)]
# Out:
#   City  Edition Sport Discipline Athlete  NOC Gender Event Event_gender Medal
# 3  NaN      NaN   NaN        NaN     NaN  NaN    NaN   NaN          NaN   NaN

# %%
olympic.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens   1896.0  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens   1896.0  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens   1896.0  Aquatics   Swimming                 NaN  AUT    Men
# 3     NaN      NaN       NaN        NaN                 NaN  NaN    NaN
# 4  Athens   1896.0  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2              100m freestyle            M  Silver
# 3                         NaN          NaN     NaN
# 4  100m freestyle for sailors            M    Gold

# %%
olympic.dropna(axis=0,how="any",inplace=True)

# %%
olympic.dropna(axis=1,how="any",thresh=5)
# Out:
#           City  Edition      Sport       Discipline  \
# 0       Athens   1896.0   Aquatics         Swimming
# 1       Athens   1896.0   Aquatics         Swimming
# 2       Athens   1896.0   Aquatics         Swimming
# 3          NaN      NaN        NaN              NaN
# 4       Athens   1896.0   Aquatics         Swimming
# 5       Athens   1896.0   Aquatics         Swimming
# 6       Athens   1896.0   Aquatics         Swimming
# 7       Athens   1896.0   Aquatics         Swimming
# 8       Athens   1896.0   Aquatics         Swimming
# 9       Athens   1896.0   Aquatics         Swimming
# 10      Athens   1896.0   Aquatics         Swimming
# 11      Athens   1896.0   Aquatics         Swimming
# 12      Athens   1896.0  Athletics        Athletics
# 13      Athens   1896.0  Athletics        Athletics
# 14      Athens   1896.0  Athletics        Athletics
# 15      Athens   1896.0  Athletics        Athletics
# 16      Athens   1896.0  Athletics        Athletics
# ...

# %%
olympic["Edition"].fillna(olympic["Edition"].mean())
# Out:
# 0        1896.000000
# 1        1896.000000
# 2        1896.000000
# 3        1967.713171
# 4        1896.000000
# 5        1896.000000
# 6        1896.000000
# 7        1896.000000
# 8        1896.000000
# 9        1896.000000
# 10       1896.000000
# 11       1896.000000
# 12       1896.000000
# 13       1896.000000
# 14       1896.000000
# 15       1896.000000
# 16       1896.000000
# 17       1896.000000
# 18       1896.000000
# 19       1896.000000
# 20       1896.000000
# 21       1896.000000
# 22       1896.000000
# 23       1896.000000
# 24       1896.000000
# 25       1896.000000
# 26       1896.000000
# 27       1896.000000
# 28       1896.000000
# 29       1896.000000
#             ...
# 29187    2008.000000
# 29188    2008.000000
# 29189    2008.000000
# 29190    2008.000000
# 29191    2008.000000
# 29192    2008.000000
# 29193    2008.000000
# 29194    2008.000000
# 29195    2008.000000
# 29196    2008.000000
# 29197    2008.000000
# 29198    2008.000000
# ...

# %%
olympic["City"].fillna("Paris").head()
# Out:
# 0    Athens
# 1    Athens
# 2    Athens
# 3     Paris
# 4    Athens
# Name: City, dtype: object

# %%
olympic.fillna({"City":"Paris","Edition":1982})
# Out:
#           City  Edition      Sport       Discipline  \
# 0       Athens   1896.0   Aquatics         Swimming
# 1       Athens   1896.0   Aquatics         Swimming
# 2       Athens   1896.0   Aquatics         Swimming
# 3        Paris   1982.0        NaN              NaN
# 4       Athens   1896.0   Aquatics         Swimming
# 5       Athens   1896.0   Aquatics         Swimming
# 6       Athens   1896.0   Aquatics         Swimming
# 7       Athens   1896.0   Aquatics         Swimming
# 8       Athens   1896.0   Aquatics         Swimming
# 9       Athens   1896.0   Aquatics         Swimming
# 10      Athens   1896.0   Aquatics         Swimming
# 11      Athens   1896.0   Aquatics         Swimming
# 12      Athens   1896.0  Athletics        Athletics
# 13      Athens   1896.0  Athletics        Athletics
# 14      Athens   1896.0  Athletics        Athletics
# 15      Athens   1896.0  Athletics        Athletics
# 16      Athens   1896.0  Athletics        Athletics
# ...

# %%
olympic.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens   1896.0  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens   1896.0  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens   1896.0  Aquatics   Swimming                 NaN  AUT    Men
# 3     NaN      NaN       NaN        NaN                 NaN  NaN    NaN
# 4  Athens   1896.0  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2              100m freestyle            M  Silver
# 3                         NaN          NaN     NaN
# 4  100m freestyle for sailors            M    Gold

# %%
olympic[olympic["Edition"].isnull()]
# Out:
#   City  Edition Sport Discipline Athlete  NOC Gender Event Event_gender Medal
# 3  NaN      NaN   NaN        NaN     NaN  NaN    NaN   NaN          NaN   NaN

# %%
help(olympic.drop)
# Out:
# Help on method drop in module pandas.core.frame:
#
# drop(labels=None, axis=0, index=None, columns=None, level=None, inplace=False, errors='raise') method of pandas.core.frame.DataFrame instance
#     Drop specified labels from rows or columns.
#
#     Remove rows or columns by specifying label names and corresponding
#     axis, or by specifying directly index or column names. When using a
#     multi-index, labels on different levels can be removed by specifying
#     the level.
#
#     Parameters
#     ----------
#     labels : single label or list-like
#         Index or column labels to drop.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Whether to drop labels from the index (0 or 'index') or
#         columns (1 or 'columns').
#     index, columns : single label or list-like
#         Alternative to specifying axis (``labels, axis=1``
#         is equivalent to ``columns=labels``).
#
#         .. versionadded:: 0.21.0
# ...

# %%
olympic.drop(["City"],axis=1)
# Out:
#        Edition      Sport       Discipline                      Athlete  NOC  \
# 0       1896.0   Aquatics         Swimming                HAJOS, Alfred  HUN
# 1       1896.0   Aquatics         Swimming             HERSCHMANN, Otto  AUT
# 2       1896.0   Aquatics         Swimming                          NaN  AUT
# 3          NaN        NaN              NaN                          NaN  NaN
# 4       1896.0   Aquatics         Swimming           MALOKINIS, Ioannis  GRE
# 5       1896.0   Aquatics         Swimming           CHASAPIS, Spiridon  GRE
# 6       1896.0   Aquatics         Swimming        CHOROPHAS, Efstathios  GRE
# 7       1896.0   Aquatics         Swimming                HAJOS, Alfred  HUN
# 8       1896.0   Aquatics         Swimming             ANDREOU, Joannis  GRE
# 9       1896.0   Aquatics         Swimming        CHOROPHAS, Efstathios  GRE
# 10      1896.0   Aquatics         Swimming                NEUMANN, Paul  AUT
# ...

# %%
# get the index of dataframe
olympic.index
# Out:
# RangeIndex(start=0, stop=29217, step=1)

# %%
olympic.drop(["NewCol"],axis=1,inplace=True)

# %%
olympic[olympic.isnull().any(axis=1)].index
# Out:
# Int64Index([2, 3], dtype='int64')

# %%
olympic.drop(olympic[olympic["City"]=="Athens"].index,axis=0)
# Out:
#           City  Edition      Sport       Discipline                   Athlete  \
# 3          NaN      NaN        NaN              NaN                       NaN
# 152      Paris   1900.0   Aquatics         Swimming            HALMAY, Zoltan
# 153      Paris   1900.0   Aquatics         Swimming       JARVIS, John Arthur
# 154      Paris   1900.0   Aquatics         Swimming               WAHLE, Otto
# 155      Paris   1900.0   Aquatics         Swimming           DROST, Johannes
# 156      Paris   1900.0   Aquatics         Swimming         HOPPENBERG, Ernst
# 157      Paris   1900.0   Aquatics         Swimming              RUBERL, Karl
# 158      Paris   1900.0   Aquatics         Swimming              RUBERL, Karl
# 159      Paris   1900.0   Aquatics         Swimming      LANE, Frederick C.V.
# 160      Paris   1900.0   Aquatics         Swimming            HALMAY, Zoltan
# 161      Paris   1900.0   Aquatics         Swimming               KEMP, Peter
# ...

# %%
olympic[olympic["City"]=="Athens"]
# Out:
#          City  Edition      Sport       Discipline  \
# 0      Athens   1896.0   Aquatics         Swimming
# 1      Athens   1896.0   Aquatics         Swimming
# 2      Athens   1896.0   Aquatics         Swimming
# 4      Athens   1896.0   Aquatics         Swimming
# 5      Athens   1896.0   Aquatics         Swimming
# 6      Athens   1896.0   Aquatics         Swimming
# 7      Athens   1896.0   Aquatics         Swimming
# 8      Athens   1896.0   Aquatics         Swimming
# 9      Athens   1896.0   Aquatics         Swimming
# 10     Athens   1896.0   Aquatics         Swimming
# 11     Athens   1896.0   Aquatics         Swimming
# 12     Athens   1896.0  Athletics        Athletics
# 13     Athens   1896.0  Athletics        Athletics
# 14     Athens   1896.0  Athletics        Athletics
# 15     Athens   1896.0  Athletics        Athletics
# 16     Athens   1896.0  Athletics        Athletics
# 17     Athens   1896.0  Athletics        Athletics
# ...

# %%
olympic[(olympic["City"]=="Athens")&(olympic["Medal"]=="Gold")].shape
# Out:
# (723, 10)

# %%
olympic[(olympic["City"]=="Athens")|(olympic["Sport"]=="Aquatics")].shape
# Out:
# (5634, 10)

# %%
olympic[olympic["City"]!="Athens"].shape
# Out:
# (27068, 10)

# %%
olympic["NewCol"]=None

# %%
olympic.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens   1896.0  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens   1896.0  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens   1896.0  Aquatics   Swimming                 NaN  AUT    Men
# 3     NaN      NaN       NaN        NaN                 NaN  NaN    NaN
# 4  Athens   1896.0  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
#
#                         Event Event_gender   Medal NewCol
# 0              100m freestyle            M    Gold   None
# 1              100m freestyle            M  Silver   None
# 2              100m freestyle            M  Silver   None
# 3                         NaN          NaN     NaN   None
# 4  100m freestyle for sailors            M    Gold   None

# %%
emp = pd.read_csv("D:/Desktop/Desktop_Important/ATI/employee.csv")

# %%
emp
# Out:
#    id     name   did
# 0   1  santosh  10.0
# 1   2    Manoj  20.0
# 2   3     Munu   NaN

# %%
dept = pd.read_csv("D:/Desktop/Desktop_Important/ATI/department.csv")

# %%
dept
# Out:
#    did      dname
# 0   10         IT
# 1   20        FIN
# 2   30      SALES
# 3   40  MARKETING

# %%
pd.merge(emp,dept,on="did",how='inner')
# Out:
#    id     name   did dname
# 0   1  santosh  10.0    IT
# 1   2    Manoj  20.0   FIN

# %%
pd.merge(emp,dept,on="did",how='left')
# Out:
#    id     name   did dname
# 0   1  santosh  10.0    IT
# 1   2    Manoj  20.0   FIN
# 2   3     Munu   NaN   NaN

# %%
pd.merge(emp,dept,on="did",how='right')
# Out:
#     id     name   did      dname
# 0  1.0  santosh  10.0         IT
# 1  2.0    Manoj  20.0        FIN
# 2  NaN      NaN  30.0      SALES
# 3  NaN      NaN  40.0  MARKETING

# %%
olympic1=olympic

# %%
type(olympic)
# Out:
# pandas.core.frame.DataFrame

# %%
type(olympic1)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.concat([olympic,olympic1],axis=0)
# Out:
#           City  Edition      Sport       Discipline  \
# 0       Athens   1896.0   Aquatics         Swimming
# 1       Athens   1896.0   Aquatics         Swimming
# 2       Athens   1896.0   Aquatics         Swimming
# 3          NaN      NaN        NaN              NaN
# 4       Athens   1896.0   Aquatics         Swimming
# 5       Athens   1896.0   Aquatics         Swimming
# 6       Athens   1896.0   Aquatics         Swimming
# 7       Athens   1896.0   Aquatics         Swimming
# 8       Athens   1896.0   Aquatics         Swimming
# 9       Athens   1896.0   Aquatics         Swimming
# 10      Athens   1896.0   Aquatics         Swimming
# 11      Athens   1896.0   Aquatics         Swimming
# 12      Athens   1896.0  Athletics        Athletics
# 13      Athens   1896.0  Athletics        Athletics
# 14      Athens   1896.0  Athletics        Athletics
# 15      Athens   1896.0  Athletics        Athletics
# 16      Athens   1896.0  Athletics        Athletics
# ...

# %%
olympic.groupby(["City"])["Medal"].count()
# Out:
# City
# Amsterdam                 710
# Antwerp                  1298
# Athens                   2149
# Atlanta                  1859
# Barcelona                1705
# Beijing                  2042
# Berlin                    875
# Helsinki                  889
# London                   1618
# Los Angeles              2074
# Melbourne / Stockholm     885
# Mexico                   1031
# Montreal                 1305
# Moscow                   1387
# Munich                   1185
# Paris                    1396
# Rome                      882
# Seoul                    1546
# St Louis                  470
# Stockholm                 885
# Sydney                   2015
# Tokyo                    1010
# Name: Medal, dtype: int64

# %%
olympic.groupby(["City"]).agg({"Medal":["count"]})
# Out:
#                       Medal
#                       count
# City
# Amsterdam               710
# Antwerp                1298
# Athens                 2149
# Atlanta                1859
# Barcelona              1705
# Beijing                2042
# Berlin                  875
# Helsinki                889
# London                 1618
# Los Angeles            2074
# Melbourne / Stockholm   885
# Mexico                 1031
# Montreal               1305
# Moscow                 1387
# Munich                 1185
# Paris                  1396
# Rome                    882
# Seoul                  1546
# St Louis                470
# Stockholm               885
# Sydney                 2015
# Tokyo                  1010

# %%
olympic.groupby(["City","Sport"]).agg({"Medal":["count"]})
# Out:
#                             Medal
#                             count
# City      Sport
# Amsterdam Aquatics             87
#           Athletics           108
#           Boxing               24
#           Cycling              39
#           Equestrian           37
#           Fencing              47
#           Football             66
#           Gymnastics           78
#           Hockey               59
#           Modern Pentathlon     3
#           Rowing               78
#           Sailing              30
#           Weightlifting        15
#           Wrestling            39
# Antwerp   Aquatics             87
#           Archery              80
#           Athletics           117
#           Boxing               24
#           Cycling              39
#           Equestrian           42
#           Fencing              76
#           Football             46
#           Gymnastics          202
#           Hockey               42
#           Ice Hockey           27
# ...

# %%
olympic.City
# Out:
# 0         Athens
# 1         Athens
# 2         Athens
# 3            NaN
# 4         Athens
# 5         Athens
# 6         Athens
# 7         Athens
# 8         Athens
# 9         Athens
# 10        Athens
# 11        Athens
# 12        Athens
# 13        Athens
# 14        Athens
# 15        Athens
# 16        Athens
# 17        Athens
# 18        Athens
# 19        Athens
# 20        Athens
# 21        Athens
# 22        Athens
# 23        Athens
# 24        Athens
# 25        Athens
# 26        Athens
# 27        Athens
# 28        Athens
# 29        Athens
#           ...
# 29187    Beijing
# 29188    Beijing
# 29189    Beijing
# 29190    Beijing
# 29191    Beijing
# 29192    Beijing
# 29193    Beijing
# 29194    Beijing
# 29195    Beijing
# 29196    Beijing
# 29197    Beijing
# 29198    Beijing
# 29199    Beijing
# 29200    Beijing
# 29201    Beijing
# 29202    Beijing
# 29203    Beijing
# 29204    Beijing
# 29205    Beijing
# 29206    Beijing
# 29207    Beijing
# ...

# %%
olympic2=olympic.set_index("Athlete")

# %%
olympic2.columns
# Out:
# Index(['City', 'Edition', 'Sport', 'Discipline', 'NOC', 'Gender', 'Event',
#        'Event_gender', 'Medal'],
#       dtype='object')

# %%
olympic2.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens   1896.0  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens   1896.0  Aquatics   Swimming  AUT    Men
# NaN                 Athens   1896.0  Aquatics   Swimming  AUT    Men
# NaN                    NaN      NaN       NaN        NaN  NaN    NaN
# MALOKINIS, Ioannis  Athens   1896.0  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# NaN                             100m freestyle            M  Silver
# NaN                                        NaN          NaN     NaN
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold

# %%
olympic2.loc["HAJOS, Alfred"]
# Out:
#                  City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred  Athens   1896.0  Aquatics   Swimming  HUN    Men
# HAJOS, Alfred  Athens   1896.0  Aquatics   Swimming  HUN    Men
#
#                          Event Event_gender Medal
# Athlete
# HAJOS, Alfred   100m freestyle            M  Gold
# HAJOS, Alfred  1200m freestyle            M  Gold

# %%
olympic1.loc[[153,154]]
# Out:
#       City  Edition     Sport Discipline              Athlete  NOC Gender  \
# 153  Paris   1900.0  Aquatics   Swimming  JARVIS, John Arthur  GBR    Men
# 154  Paris   1900.0  Aquatics   Swimming          WAHLE, Otto  AUT    Men
#
#                Event Event_gender   Medal
# 153  1500m freestyle            M    Gold
# 154  1500m freestyle            M  Silver

# %%
olympic.loc[1:5,"City":"Athlete"]
# Out:
#      City  Edition     Sport Discipline             Athlete
# 1  Athens   1896.0  Aquatics   Swimming    HERSCHMANN, Otto
# 2  Athens   1896.0  Aquatics   Swimming                 NaN
# 3     NaN      NaN       NaN        NaN                 NaN
# 4  Athens   1896.0  Aquatics   Swimming  MALOKINIS, Ioannis
# 5  Athens   1896.0  Aquatics   Swimming  CHASAPIS, Spiridon

# %%
olympic.iloc[0:5,0:2]
# Out:
#      City  Edition
# 0  Athens   1896.0
# 1  Athens   1896.0
# 2  Athens   1896.0
# 3     NaN      NaN
# 4  Athens   1896.0

# %%
data = pd.read_csv("D:/Desktop/Desktop_Important/ATI/CityTaxi/test.csv")

# %%
data.head()
# Out:
#                            key          pickup_datetime  pickup_longitude  \
# 0  2015-01-27 13:08:24.0000002  2015-01-27 13:08:24 UTC        -73.973320
# 1  2015-01-27 13:08:24.0000003  2015-01-27 13:08:24 UTC        -73.986862
# 2  2011-10-08 11:53:44.0000002  2011-10-08 11:53:44 UTC        -73.982524
# 3  2012-12-01 21:12:12.0000002  2012-12-01 21:12:12 UTC        -73.981160
# 4  2012-12-01 21:12:12.0000003  2012-12-01 21:12:12 UTC        -73.966046
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 0        40.763805         -73.981430         40.743835                1
# 1        40.719383         -73.998886         40.739201                1
# 2        40.751260         -73.979654         40.746139                1
# 3        40.767807         -73.990448         40.751635                1
# 4        40.789775         -73.988565         40.744427                1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9914 entries, 0 to 9913
# Data columns (total 7 columns):
# key                  9914 non-null object
# pickup_datetime      9914 non-null datetime64[ns]
# pickup_longitude     9914 non-null float64
# pickup_latitude      9914 non-null float64
# dropoff_longitude    9914 non-null float64
# dropoff_latitude     9914 non-null float64
# passenger_count      9914 non-null int64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 542.2+ KB

# %%
data["pickup_datetime"] = pd.to_datetime(data["pickup_datetime"])

# %%
data["pickup_datetime"].dt.year
# Out:
# 0       2015
# 1       2015
# 2       2011
# 3       2012
# 4       2012
# 5       2012
# 6       2011
# 7       2011
# 8       2011
# 9       2014
# 10      2014
# 11      2014
# 12      2010
# 13      2010
# 14      2011
# 15      2011
# 16      2012
# 17      2012
# 18      2012
# 19      2012
# 20      2014
# 21      2014
# 22      2014
# 23      2014
# 24      2014
# 25      2014
# 26      2014
# 27      2014
# 28      2014
# 29      2014
#         ...
# 9884    2013
# 9885    2013
# 9886    2013
# 9887    2013
# 9888    2013
# 9889    2013
# 9890    2013
# 9891    2013
# 9892    2013
# 9893    2013
# 9894    2013
# 9895    2013
# 9896    2013
# 9897    2015
# 9898    2015
# 9899    2015
# 9900    2015
# 9901    2015
# 9902    2015
# 9903    2015
# 9904    2015
# 9905    2015
# 9906    2015
# 9907    2015
# 9908    2015
# 9909    2015
# 9910    2015
# 9911    2015
# 9912    2015
# 9913    2015
# Name: pickup_datetime, Length: 9914, dtype: int64

# %%
a='2019/10/01'

# %%
a
# Out:
# '2019/10/01'

# %%
print(pd.to_datetime(a))
# Out:
# 2019-10-01 00:00:00

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# read_csv(filepath_or_buffer, sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, escapechar=None, comment=None, encoding=None, dialect=None, tupleize_cols=None, error_bad_lines=True, warn_bad_lines=True, skipfooter=0, doublequote=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
#     Read CSV (comma-separated) file into DataFrame
#
# ...
